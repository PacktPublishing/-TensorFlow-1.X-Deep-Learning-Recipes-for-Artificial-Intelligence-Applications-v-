# %% [markdown]
# # Building an image classifier with CNNs
#
# Dataset of 60,000 28x28 grayscale images of 10 fashion categories, along with a test set of 10,000 images. This dataset can be used as a drop-in replacement for MNIST. The class labels are:
#
# Label Description
#
# - 0 T-shirt/top
# - 1 Trouser
# - 2 Pullover
# - 3 Dress
# - 4 Coat
# - 5 Sandal
# - 6 Shirt
# - 7 Sneaker
# - 8 Bag
# - 9 Ankle boot
#
# This dataset is available from Keras

# %% [markdown]
# ## Importing the necessary libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# C:\Users\direc\Anaconda3\envs\recipes-ai\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Loading the dataset

# %%
from keras.datasets import fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

n_train = y_train.shape[0]
n_test = y_test.shape[0]
n_categories = 10
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Take a look at the dataset

# %%
categories = {0:'T-shirt/top', 1:'Trouser', 2:'Pullover', 3:'Dress', 4:'Coat',
                 5:'Sandal', 6:'Shirt', 7:'Sneaker', 8:'Bag', 9:'Ankle boot'}

fig, axes = plt.subplots(nrows=4, ncols=8, figsize=(13,6))
for i, ax in enumerate(axes.flatten()):
    ax.imshow(X_train[i], cmap='Greys')
    ax.set_title(categories[y_train[i]])
    ax.axis('off')

fig.tight_layout()

# %% [markdown]
# ## Preprocesing the data

# %%
## Reshaping and rescaling images:
X_train = X_train.reshape(n_train, 28, 28, 1)/255.
X_test = X_test.reshape(n_test, 28, 28, 1)/255.

## Getting validation and test sets
X_val = X_test[:1000]
X_test = X_test[1000:]

y_val = y_test[:1000]
y_test = y_test[1000:]
## Here we can use 1000 for test and validation and the reset for training

# %% [markdown]
# ## Build the input pipeline

# %%
BATCH_SIZE = 128

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=10000)
train_dataset = train_dataset.batch(BATCH_SIZE)
iterator = train_dataset.make_initializable_iterator()
next_element = iterator.get_next()

# %% [markdown]
# ## Building the CNN model

# %%
def cnn(inputs):
    ## Convolution + max_pooling 1
    conv1 = tf.layers.conv2d(inputs, filters=32, kernel_size=3,
                             strides=1, padding='same', activation=tf.nn.relu)
    max_pooling1 = tf.layers.max_pooling2d(conv1, pool_size=2, strides=2, padding='same')
    
    ## Convolution + max_pooling 2
    conv2 = tf.layers.conv2d(max_pooling1, filters=64, kernel_size=3,
                             strides=1, padding='same', activation=tf.nn.relu)
    max_pooling2 = tf.layers.max_pooling2d(conv2, pool_size=2, strides=2, padding='same')
    
    ## Flatten + dense
    flatten = tf.layers.flatten(max_pooling2)
    dense = tf.layers.dense(flatten, units=128, activation=tf.nn.relu)
    
    ## Output
    logits = tf.layers.dense(dense, units=n_categories)
    return logits

# %% [markdown]
# ## Create placeholders to pass values for training and evaluation

# %%
X_placeholder_shape = [None] + list(X_train.shape[1:])
X = tf.placeholder(tf.float32, shape=X_placeholder_shape)
y = tf.placeholder(tf.int32)

# %% [markdown]
# ## Define the loss, optimizer and training operation

# %%
logits = cnn(X)
loss = tf.losses.sparse_softmax_cross_entropy(labels=y, logits=logits)
optimizer = tf.train.RMSPropOptimizer(learning_rate=0.01)
training_op = optimizer.minimize(loss)

# %% [markdown]
# ## Getting predictions and metrics

# %%
y_pred_proba = tf.nn.softmax(logits)
y_pred = tf.argmax(y_pred_proba, axis=1, output_type=tf.int32)

correct = tf.equal(y_pred, y)
accuracy = 100*tf.reduce_mean(tf.cast(correct, tf.float32))

# %% [markdown]
# ## Write a function for running the training operation

# %%
def train_model(epoch):
    iterator.initializer.run()
    while True:
        try:
            X_values, y_values = sess.run(next_element)
            sess.run(training_op, feed_dict={X: X_values, y:y_values})
        except tf.errors.OutOfRangeError:
            break
    train_acc = sess.run(accuracy, feed_dict={X:X_values, y:y_values})
    val_acc = sess.run(accuracy, feed_dict={X: X_val, y:y_val})
    print('Epoch: {:d}, Training Accuracy: {:0.2f}% | Validation Accuracy {:0.2f}%'.format(epoch, train_acc, val_acc))
    return train_acc, val_acc

# %% [markdown]
# ## Run the computational graph

# %%
N_EPOCHS = 50
accuracy_metrics = np.zeros((N_EPOCHS, 2))
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    for epoch in range(N_EPOCHS):
        accuracy_metrics[epoch] = train_model(epoch+1)
    print("Done training")
    test_preds = sess.run(y_pred_proba, feed_dict={X: X_test[:1500], y:y_test[:1500]})
# Out:
# Epoch: 1, Training Accuracy: 91.67% | Validation Accuracy 87.70%
# Epoch: 2, Training Accuracy: 96.88% | Validation Accuracy 88.20%
# Epoch: 3, Training Accuracy: 93.75% | Validation Accuracy 88.20%
# Epoch: 4, Training Accuracy: 95.83% | Validation Accuracy 91.00%
# Epoch: 5, Training Accuracy: 96.88% | Validation Accuracy 90.00%
# Epoch: 6, Training Accuracy: 98.96% | Validation Accuracy 89.70%
# Epoch: 7, Training Accuracy: 96.88% | Validation Accuracy 90.20%
# Epoch: 8, Training Accuracy: 97.92% | Validation Accuracy 88.20%
# Epoch: 9, Training Accuracy: 97.92% | Validation Accuracy 90.00%
# Epoch: 10, Training Accuracy: 97.92% | Validation Accuracy 89.10%
# Epoch: 11, Training Accuracy: 98.96% | Validation Accuracy 89.40%
# Epoch: 12, Training Accuracy: 97.92% | Validation Accuracy 89.30%
# Epoch: 13, Training Accuracy: 100.00% | Validation Accuracy 88.90%
# Epoch: 14, Training Accuracy: 98.96% | Validation Accuracy 90.40%
# Epoch: 15, Training Accuracy: 92.71% | Validation Accuracy 89.10%
# Epoch: 16, Training Accuracy: 95.83% | Validation Accuracy 88.70%
# Epoch: 17, Training Accuracy: 93.75% | Validation Accuracy 89.40%
# Epoch: 18, Training Accuracy: 92.71% | Validation Accuracy 88.50%
# Epoch: 19, Training Accuracy: 100.00% | Validation Accuracy 90.20%
# Epoch: 20, Training Accuracy: 98.96% | Validation Accuracy 89.20%
# Epoch: 21, Training Accuracy: 96.88% | Validation Accuracy 90.10%
# Epoch: 22, Training Accuracy: 91.67% | Validation Accuracy 88.00%
# Epoch: 23, Training Accuracy: 96.88% | Validation Accuracy 89.30%
# Epoch: 24, Training Accuracy: 95.83% | Validation Accuracy 90.20%
# Epoch: 25, Training Accuracy: 94.79% | Validation Accuracy 90.10%
# Epoch: 26, Training Accuracy: 93.75% | Validation Accuracy 89.10%
# Epoch: 27, Training Accuracy: 95.83% | Validation Accuracy 89.50%
# Epoch: 28, Training Accuracy: 93.75% | Validation Accuracy 88.10%
# Epoch: 29, Training Accuracy: 95.83% | Validation Accuracy 88.50%
# Epoch: 30, Training Accuracy: 97.92% | Validation Accuracy 90.30%
# Epoch: 31, Training Accuracy: 95.83% | Validation Accuracy 87.70%
# Epoch: 32, Training Accuracy: 98.96% | Validation Accuracy 88.60%
# Epoch: 33, Training Accuracy: 100.00% | Validation Accuracy 90.40%
# Epoch: 34, Training Accuracy: 94.79% | Validation Accuracy 90.40%
# Epoch: 35, Training Accuracy: 93.75% | Validation Accuracy 89.00%
# Epoch: 36, Training Accuracy: 93.75% | Validation Accuracy 88.10%
# Epoch: 37, Training Accuracy: 100.00% | Validation Accuracy 90.30%
# Epoch: 38, Training Accuracy: 95.83% | Validation Accuracy 88.90%
# Epoch: 39, Training Accuracy: 96.88% | Validation Accuracy 89.60%
# Epoch: 40, Training Accuracy: 95.83% | Validation Accuracy 89.10%
# Epoch: 41, Training Accuracy: 95.83% | Validation Accuracy 90.40%
# Epoch: 42, Training Accuracy: 97.92% | Validation Accuracy 89.60%
# Epoch: 43, Training Accuracy: 96.88% | Validation Accuracy 89.20%
# Epoch: 44, Training Accuracy: 96.88% | Validation Accuracy 89.10%
# Epoch: 45, Training Accuracy: 93.75% | Validation Accuracy 89.80%
# Epoch: 46, Training Accuracy: 95.83% | Validation Accuracy 88.60%
# Epoch: 47, Training Accuracy: 92.71% | Validation Accuracy 86.70%
# Epoch: 48, Training Accuracy: 94.79% | Validation Accuracy 90.10%
# Epoch: 49, Training Accuracy: 94.79% | Validation Accuracy 89.90%
# Epoch: 50, Training Accuracy: 94.79% | Validation Accuracy 88.00%
# Done training

# %% [markdown]
# ## Evaluation metrics

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(np.arange(N_EPOCHS), accuracy_metrics[:,0], 'o-', label='Training')
ax.plot(np.arange(N_EPOCHS), accuracy_metrics[:,1], 'o-', label='Validation')
ax.legend(); ax.grid()
ax.set_title('Accuracy');

# %% [markdown]
# ## Testing accuracy on the first 1500 test elements

# %%
test_acc = 100*np.mean(np.argmax(test_preds, axis=1) == y_test[:1500])
print("Test Accuracy: {:0.2f}%".format(test_acc))
# Out:
# Test Accuracy: 87.87%

# %% [markdown]
# ## Distribution of prediction probabilities

# %%
fig, ax = plt.subplots(figsize=(8,5))
prob_max = np.max(test_preds, 1)
ax.hist(prob_max, bins=50);
